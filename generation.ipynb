# %%
import faker
import pandas as pd
from sqlalchemy import create_engine,text
import random
import mysql.connector

# %%
# create a connection with a mysql database
engine = create_engine('mysql+mysqlconnector://root:root@localhost/db_restaurante')

# %%
def insert_empresa():
    fake = faker.Faker('pt_BR')
    data = []
    for _ in range(5):  # Para cada empresa
        num_funcionarios = random.randint(1, 5)  # Número aleatório de funcionários entre 1 e 10
        empresa = fake.company()
        for _ in range(num_funcionarios):  # Adicionar funcionários para a empresa
            data.append({
                'nome_empresa': empresa,
                'nome_funcionario_empresa': fake.name(),
            })
    df = pd.DataFrame(data)
    df.to_sql('st_empresa', con=engine, if_exists='append', index=False)
    return data

# %%
insert_empresa()
# Out:
# [{'nome_empresa': 'Ferreira', 'nome_funcionario_empresa': 'Miguel Cavalcante'},
#  {'nome_empresa': 'Ferreira', 'nome_funcionario_empresa': 'Julia Campos'},
#  {'nome_empresa': 'Ferreira', 'nome_funcionario_empresa': 'Alícia Rocha'},
#  {'nome_empresa': 'Sousa e Filhos',
#   'nome_funcionario_empresa': 'Ana Cecília Porto'},
#  {'nome_empresa': 'Sousa e Filhos',
#   'nome_funcionario_empresa': 'Sr. Gael Henrique Leão'},
#  {'nome_empresa': 'Sousa e Filhos',
#   'nome_funcionario_empresa': 'Vitor Camargo'},
#  {'nome_empresa': 'Sousa e Filhos',
#   'nome_funcionario_empresa': 'Olivia Guerra'},
#  {'nome_empresa': 'Sousa e Filhos',
#   'nome_funcionario_empresa': 'Matteo Macedo'},
#  {'nome_empresa': 'Dias', 'nome_funcionario_empresa': 'Larissa Mendes'},
#  {'nome_empresa': 'Dias', 'nome_funcionario_empresa': 'Emanuella Vieira'},
#  {'nome_empresa': 'Dias', 'nome_funcionario_empresa': 'Eduarda Moreira'},
#  {'nome_empresa': 'Dias', 'nome_funcionario_empresa': 'Davi Luiz Aragão'},
# ...

# %%
def insert_clients():
    fake = faker.Faker('pt_BR')
    funcionarios = insert_empresa()
    
    # Extrair nomes dos funcionários
    nomes_funcionarios = [f['nome_funcionario_empresa'] for f in funcionarios]
    
    # Gerar clientes adicionais (sem repetir os nomes dos funcionários)
    num_clientes_total = 50
    num_clientes_adicionais = num_clientes_total - len(nomes_funcionarios)
    
    data = []
    
    # Adicionar funcionários como clientes
    for nome_funcionario in nomes_funcionarios:
        data.append({
            'cpf_cliente': fake.cpf(),
            'nome_cliente': nome_funcionario,
            'telefone_cliente': fake.phone_number(),
            'email_cliente': fake.email()
        })
    
    # Adicionar clientes aleatórios
    for _ in range(num_clientes_adicionais):
        data.append({
            'cpf_cliente': fake.cpf(),
            'nome_cliente': fake.name(),
            'telefone_cliente': fake.phone_number(),
            'email_cliente': fake.email()
        })
        
    df = pd.DataFrame(data)
    df.to_sql('st_cliente', con=engine, if_exists='append', index=False)
    return data

# %%
insert_clients()
# Out:
# [{'cpf_cliente': '260.139.754-34',
#   'nome_cliente': 'Thomas Cirino',
#   'telefone_cliente': '+55 84 9616 9981',
#   'email_cliente': 'qrocha@example.net'},
#  {'cpf_cliente': '954.187.326-09',
#   'nome_cliente': 'Emanuel Brito',
#   'telefone_cliente': '0900-968-3327',
#   'email_cliente': 'dborges@example.net'},
#  {'cpf_cliente': '036.148.297-31',
#   'nome_cliente': 'Samuel Nascimento',
#   'telefone_cliente': '0500 976 4038',
#   'email_cliente': 'ferreiraana-clara@example.com'},
#  {'cpf_cliente': '875.641.392-00',
#   'nome_cliente': 'Hadassa Monteiro',
#   'telefone_cliente': '+55 51 2410 5915',
#   'email_cliente': 'yagosiqueira@example.org'},
#  {'cpf_cliente': '174.605.892-76',
#   'nome_cliente': 'Fernanda Lopes',
#   'telefone_cliente': '+55 84 8443 2587',
#   'email_cliente': 'da-costaeloah@example.net'},
#  {'cpf_cliente': '125.893.704-23',
#   'nome_cliente': 'Josué Oliveira',
#   'telefone_cliente': '81 0424-2027',
#   'email_cliente': 'paulo94@example.org'},
# ...

# %%
clientes_gerados = insert_clients()

# Exibir os nomes dos clientes gerados
print("Nomes dos clientes gerados:")
for cliente in clientes_gerados:
    print(cliente['nome_cliente'])
# Out:
# Nomes dos clientes gerados:
# Arthur Pereira
# Maria Dias
# Vitória da Costa
# Arthur Gabriel Melo
# Liam Sousa
# Maria Flor Cirino
# Srta. Cecilia Viana
# Alícia Rios
# João Felipe Correia
# Bento Rezende
# Ana Lívia Novaes
# Sophia Machado
# Nina Dias
# Kamilly Fernandes
# Breno Martins
# Josué Araújo
# Joana Barros
# Leandro Montenegro
# Zoe Sousa
# Srta. Lavínia Andrade
# Maria Clara da Mota
# Erick Fonseca
# Gabriel da Mota
# Maria Júlia Fonseca
# Gabriela Ramos
# Gael Henrique Pimenta
# Srta. Alexia Vasconcelos
# Melissa Almeida
# Carolina Farias
# Maya da Rosa
# Maria Helena Gomes
# Luiz Henrique Aparecida
# Marcelo Novais
# Olivia Lima
# Sra. Ísis Sá
# Júlia Garcia
# Maria Liz da Costa
# João Pedro Caldeira
# Bella Marques
# Gustavo Henrique Pacheco
# Caleb Novaes
# Heloisa Gonçalves
# Augusto Melo
# Renan Abreu
# Maria Cecília da Luz
# Giovanna Machado
# Dante da Conceição
# Ana Lívia Oliveira
# Natália Azevedo
# Yago Nunes
